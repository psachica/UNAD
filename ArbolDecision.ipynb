# %% [markdown]
# 1. Realizar un análisis exploratorio de los datos para identificar relaciones entre variables, valores atípicos, tendencias, etc.

# %%
#Importamos las librerias 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
#Cargamos el dataset y mostramos las 5 primeras filas
data = pd.read_csv('C:/Users/sachi/Downloads/winequality-red.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# 2. Preprocesar los datos limpiándolos, tratando valores faltantes y transformándolos según sea necesario

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# 3. Seleccionar las características más relevantes para entrenar el modelo utilizando selección de características

# %%
plt.hist(data.quality)
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x = "fixed acidity", y = "volatile acidity", hue = "quality", data = data)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='volatile acidity'>

# %%
sns.scatterplot(x = "free sulfur dioxide", y = "total sulfur dioxide", hue = "quality", data = data)
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='total sulfur dioxide'>

# %%
sns.scatterplot(x = "citric acid", y = "residual sugar", hue = "quality", data = data)
# Out:
# <Axes: xlabel='citric acid', ylabel='residual sugar'>

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(data=data[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','density','pH','sulphates','alcohol']])
plt.xticks(rotation=45)
plt.title('Boxplot de propiedades del vino')
plt.ylabel('Valores')
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(data=data[['free sulfur dioxide','total sulfur dioxide']])
plt.xticks(rotation=45)
plt.title('Boxplot de propiedades del vino')
plt.ylabel('Valores')
plt.show()

# %%
predictors_col = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']
target_col = ['quality']

# %%
predictors = data[predictors_col]
target = data[target_col]

# %%
predictors
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
corr = predictors.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# ...

# %%
sns.heatmap(corr)
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# 4. Dividir el dataset en Train y Test para evaluar correctamente el modelo
# 5. Entrenar el modelo configurando los diferentes hiperparámetros
# 6. Evaluar el desempeño del modelo en el conjunto de Test con métricas como precisión, recall, F1-score, etc

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.2, random_state=13)

# %%
tree = DecisionTreeClassifier()

# %%
arbol = tree.fit(X_train, y_train)

# %%
plot_tree(arbol)
# Out:
# [Text(0.5145597245255206, 0.9772727272727273, 'x[10] <= 10.525\ngini = 0.646\nsamples = 1279\nvalue = [9.0, 45.0, 535.0, 514.0, 164.0, 12.0]'),
#  Text(0.23601130151710584, 0.9318181818181818, 'x[9] <= 0.535\ngini = 0.546\nsamples = 774\nvalue = [6, 29, 450, 260, 29, 0]'),
#  Text(0.3752855130213132, 0.9545454545454546, 'True  '),
#  Text(0.04213500399238376, 0.8863636363636364, 'x[1] <= 0.335\ngini = 0.367\nsamples = 183\nvalue = [2, 13, 143, 24, 1, 0]'),
#  Text(0.015723849886370617, 0.8409090909090909, 'x[4] <= 0.082\ngini = 0.562\nsamples = 11\nvalue = [0, 1, 4, 6, 0, 0]'),
#  Text(0.011792887414777962, 0.7954545454545454, 'x[2] <= 0.375\ngini = 0.406\nsamples = 8\nvalue = [0, 1, 1, 6, 0, 0]'),
#  Text(0.007861924943185309, 0.75, 'x[6] <= 85.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.003930962471592654, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
# ...

# %%
predicciones = arbol.predict(X_test)

# %%
predicciones
# Out:
# array([7, 7, 5, 5, 6, 5, 5, 8, 6, 7, 5, 6, 5, 6, 7, 5, 6, 7, 5, 7, 5, 6,
#        7, 5, 6, 5, 6, 5, 6, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 7, 6, 5, 6, 6,
#        6, 5, 6, 5, 5, 6, 6, 4, 6, 5, 7, 5, 5, 6, 6, 5, 6, 5, 5, 5, 7, 7,
#        6, 7, 5, 6, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 8, 6, 6, 5, 5, 5, 6, 5,
#        7, 5, 6, 6, 5, 7, 7, 6, 5, 5, 6, 6, 5, 7, 6, 5, 6, 6, 6, 6, 5, 7,
#        7, 7, 6, 6, 5, 5, 6, 7, 5, 5, 7, 4, 5, 6, 5, 4, 5, 5, 6, 7, 6, 5,
#        6, 7, 5, 5, 7, 5, 6, 7, 5, 5, 6, 6, 6, 4, 6, 6, 6, 5, 5, 6, 5, 6,
#        5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 6, 5, 6, 5, 6, 5, 5, 5, 5, 5, 6, 5,
#        5, 5, 5, 5, 5, 6, 6, 6, 5, 5, 6, 6, 5, 5, 5, 6, 5, 5, 7, 5, 6, 7,
#        5, 5, 6, 6, 7, 5, 6, 6, 6, 5, 5, 6, 5, 5, 6, 6, 7, 5, 5, 5, 6, 7,
#        5, 5, 6, 5, 6, 6, 5, 5, 4, 6, 6, 6, 5, 5, 5, 6, 6, 5, 5, 5, 5, 6,
#        6, 6, 5, 6, 8, 5, 5, 6, 6, 6, 5, 5, 6, 6, 6, 7, 5, 5, 6, 6, 5, 5,
#        6, 5, 6, 7, 6, 5, 5, 5, 6, 5, 6, 5, 6, 6, 5, 5, 5, 4, 6, 5, 7, 5,
# ...

# %%
# Examinamos la matriz de confusión
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['Actual'], colnames=['Predicciones'])
# Out:
# Predicciones  4    5   6   7  8
# Actual
# 3             0    0   1   0  0
# 4             3    3   1   1  0
# 5             1  106  33   6  0
# 6             3   36  72  11  2
# 7             0    4  11  20  0
# 8             0    2   2   1  1

# %%
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.63125

# %%
precision = precision_score(y_test, predicciones, average='weighted', zero_division=1)
precision
# Out:
# 0.6289604862576716

# %%
recall = recall_score(y_test, predicciones, average='weighted')
recall
# Out:
# 0.63125

# %%
f1 = f1_score(y_test, predicciones, average='weighted')
f1
# Out:
# 0.6276502135518529

# %% [markdown]
# Interpretación de los resultados
#
# El modelo de árbol de decisión logra una precisión aproximada del 62.9%, lo que significa que acierta en casi 63 de cada 100 predicciones al clasificar la calidad del vino. Aunque el modelo demuestra un rendimiento razonable, todavía tiene margen de mejora, especialmente en clases con pocos ejemplos o menos representadas. En general, es un buen punto de partida y puede ofrecer predicciones útiles, aunque no perfectas.
